# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#importando datasets
url = 'https://github.com/Alexandremw76/Projeto_icdi/raw/master/Data_set/IDH.csv'
url1='https://github.com/Alexandremw76/Projeto_icdi/raw/master/Data_set/PIB.csv'
url2='https://github.com/Alexandremw76/Projeto_icdi/raw/master/Data_set/POP.csv'

df_IDH=pd.read_csv(url) #apartir de 1990
df_PIB=pd.read_csv(url1)#apartir de 1990
df_POP=pd.read_csv(url2)#apartir de 1990

# %% [markdown]
# # Calculando media e desvio padrao

# %%
#calculando media
mean_pop=df_POP[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].mean()
mean_pib=df_PIB[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].mean()
mean_idh=df_IDH[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].mean()
#calculando desvio padrão
ds_pop=df_POP[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].std()
ds_pib=df_PIB[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].std()
ds_idh=df_IDH[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].std()
# Out:
# C:\Users\Alexandre\AppData\Local\Temp\ipykernel_5964\3075439445.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_pop=df_POP[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].mean()
# Australia          17.706143
# Canada             29.112286
# Colombia           35.544000
# Costa Rica          3.358000
# France             59.238714
# Italy              56.856000
# United States     263.516143
# United Kingdom     58.118714
# dtype: float64

# %%
#calculando desvio padrão
ds_pop=df_POP[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].std()
ds_pib=df_PIB[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].std()
ds_idh=df_IDH[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].std()

# %%
#boxplot de populaçao
boxplot_pop=df_POP[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].boxplot()

# %%
#boxplot de pib
boxplot_pib=df_PIB[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].boxplot()

# %%
#boxplot de idh
boxplot_idh=df_IDH[["Australia","Canada","Colombia","Costa Rica","France","China","Italy","United States","United Kingdom"]].iloc[1:8].boxplot()

# %% [markdown]
# # Vizualizaçao de dados

# %%
sns.scatterplot(data=df_IDH, x="China", y="United States",hue="Years")
# Out:
# <AxesSubplot:xlabel='China', ylabel='United States'>

# %%
sns.histplot([df_IDH[["United States"]], df_POP[["United States"]]], color=['r','b'], alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [131], in <cell line: 3>()
#       1 oi=np.array(df_IDH[["United States"]]),(df_POP[["United States"]])
#       2 oi
# ----> 3 sns.histplot([df_IDH[["United States"]], df_POP[["United States"]]], color=['r','b'], alpha=0.5)
#
# File C:\Program Files\Python38\lib\site-packages\seaborn\distributions.py:1430, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1409 def histplot(
#    1410     data=None, *,
#    1411     # Vector variables
#    (...)
#    1427     **kwargs,
#    1428 ):
# -> 1430     p = _DistributionPlotter(
#    1431         data=data,
# ...
